# %% [markdown]
# ## Exploring Data and Linear Regression

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
ames = pd.read_csv("Amestrain.csv", error_bad_lines=False)
z = ames['GrLivArea']+ames['BsmtUnfSF']<4000
data = ames[z]
nums0 = data.select_dtypes(include=['int64','float64'])
nums=nums0.dropna()
nums.head(5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# ...

# %% [markdown]
# # Histograms for Numerical Features

# %%
nums.hist(bins=50, figsize=(40,30))
plt.show()

# %% [markdown]
# # Scatter Plots of Numerical Data vs. Price
# I could not get the axis or title labels to display properly, but I labeled each graph manually.

# %%
for i in range(0,len(nums.columns)):
    fig_i, ax_i=plt.subplots()
    ax_i.plot(nums[nums.columns[i]].tolist(),nums.SalePrice,'x', color='Blue')
    ax_i.set_xlabel=nums.columns[i]
    ax_i.set_ylabel=("Sale Price")
    ax_i.set_title=nums.columns[i],"vs Sale Price"
    fig_i.set_size_inches(5,5)
    print(nums.columns[i],'vs Sale Price')
    plt.show()
# Out:
# Id vs Sale Price
# MSSubClass vs Sale Price
# LotFrontage vs Sale Price
# LotArea vs Sale Price
# OverallQual vs Sale Price
# OverallCond vs Sale Price
# YearBuilt vs Sale Price
# YearRemodAdd vs Sale Price
# MasVnrArea vs Sale Price
# BsmtFinSF1 vs Sale Price
# BsmtFinSF2 vs Sale Price
# BsmtUnfSF vs Sale Price
# TotalBsmtSF vs Sale Price
# 1stFlrSF vs Sale Price
# 2ndFlrSF vs Sale Price
# LowQualFinSF vs Sale Price
# GrLivArea vs Sale Price
# BsmtFullBath vs Sale Price
# BsmtHalfBath vs Sale Price
# FullBath vs Sale Price
# HalfBath vs Sale Price
# BedroomAbvGr vs Sale Price
# KitchenAbvGr vs Sale Price
# TotRmsAbvGrd vs Sale Price
# Fireplaces vs Sale Price
# GarageYrBlt vs Sale Price
# GarageCars vs Sale Price
# GarageArea vs Sale Price
# WoodDeckSF vs Sale Price
# OpenPorchSF vs Sale Price
# EnclosedPorch vs Sale Price
# 3SsnPorch vs Sale Price
# ScreenPorch vs Sale Price
# PoolArea vs Sale Price
# MiscVal vs Sale Price
# MoSold vs Sale Price
# YrSold vs Sale Price
# ...

# %% [markdown]
# # Linear Regression and Model Prediction
# I could not get the axis or title labels to display properly, but I labeled each of the equations.

# %%
import sklearn as sk
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
for i in range(0,len(nums.columns)-1):
        fig_i, ax_i=plt.subplots()        
        ax_i.plot(nums[nums.columns[i]].tolist(),nums.SalePrice,'x', color='Blue')
        ax_i.set_xlabel=nums.columns[i]
        ax_i.set_ylabel=("Sale Price")
        ax_i.set_title=nums.columns[i]+"vs Sale Price"
        fig_i.set_size_inches(5,5)
        lin_i=plt.subplot()
        linear_regressor_i=LinearRegression()
        x_i=nums[nums.columns[i]].values.reshape(-1,1)
        y_i=nums.SalePrice.values.reshape(-1,1)
        linear_regressor_i.fit(x_i,y_i)
        price_pred_i=linear_regressor_i.predict(x_i)
        lin_i.plot(x_i,price_pred_i,color='Red')
        lin_i.set_xlabel=nums.columns[i]
        lin_i.set_ylabel=("Sale Price")
        lin_i.set_title=("Sale Price vs", nums.columns[i])
        slope=linear_regressor_i.coef_
        intercept=linear_regressor_i.intercept_
        print(nums.columns[i],'vs Sale Price')
        print('Regression Equation: y=', slope[0][0],'x + ', intercept[0])
        print('RSS:',np.sum((y_i-price_pred_i)**2))
        plt.show()
# Out:
# Id vs Sale Price
# Regression Equation: y= -9.80770540716749 x +  188149.89509386974
# RSS: 5988453057737.068
# MSSubClass vs Sale Price
# Regression Equation: y= -170.1570770996166 x +  190578.0694847507
# RSS: 5950842423588.433
# LotFrontage vs Sale Price
# Regression Equation: y= 1081.2692468072416 x +  105353.9823743093
# RSS: 5333539605322.047
# LotArea vs Sale Price
# Regression Equation: y= 2.770154256678685 x +  153450.54574161876
# RSS: 5477912293321.206
# OverallQual vs Sale Price
# Regression Equation: y= 44787.67122807459 x +  -94758.53202522654
# RSS: 2116103898787.832
# OverallCond vs Sale Price
# Regression Equation: y= -9948.72010605963 x +  236326.2583351461
# RSS: 5884762610561.257
# YearBuilt vs Sale Price
# Regression Equation: y= 1378.388707543162 x +  -2537136.0704716505
# RSS: 4042329405882.34
# YearRemodAdd vs Sale Price
# Regression Equation: y= 1922.5986404433825 x +  -3635998.8624554644
# RSS: 4204871224722.16
# MasVnrArea vs Sale Price
# ...
